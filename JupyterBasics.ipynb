# %%
print("Hello World")
# Out:
# Hello World

# %%
a = (11/4)
print(type(a))
# Out:
# <class 'float'>

# %%
name = "sandip"
print(type(name))
# Out:
# <class 'str'>

# %%
type(31//4)
# Out:
# int

# %%
a = 31//4
print(a)
# Out:
# 7

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('polls.csv')
#data.random(100)

# %%
data.shape
# Out:
# (12624, 27)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12624 entries, 0 to 12623
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   cycle             12624 non-null  int64
#  1   branch            12624 non-null  object
#  2   type              12624 non-null  object
#  3   matchup           12624 non-null  object
#  4   forecastdate      12624 non-null  object
#  5   state             12624 non-null  object
#  6   startdate         12624 non-null  object
#  7   enddate           12624 non-null  object
#  8   pollster          12624 non-null  object
#  9   grade             11337 non-null  object
#  10  samplesize        12621 non-null  float64
#  11  population        12624 non-null  object
#  12  poll_wt           12624 non-null  float64
#  13  rawpoll_clinton   12624 non-null  float64
#  14  rawpoll_trump     12624 non-null  float64
#  15  rawpoll_johnson   8397 non-null   float64
# ...

# %%
needed_cols = ['matchup', 'forecastdate']
data[needed_cols]
# Out:
#                              matchup forecastdate
# 0      Clinton vs. Trump vs. Johnson      11/8/16
# 1      Clinton vs. Trump vs. Johnson      11/8/16
# 2      Clinton vs. Trump vs. Johnson      11/8/16
# 3      Clinton vs. Trump vs. Johnson      11/8/16
# 4      Clinton vs. Trump vs. Johnson      11/8/16
# ...                              ...          ...
# 12619  Clinton vs. Trump vs. Johnson      11/8/16
# 12620  Clinton vs. Trump vs. Johnson      11/8/16
# 12621  Clinton vs. Trump vs. Johnson      11/8/16
# 12622  Clinton vs. Trump vs. Johnson      11/8/16
# 12623  Clinton vs. Trump vs. Johnson      11/8/16
#
# [12624 rows x 2 columns]

# %% [markdown]
# ### object is a string data type

# %%
data[['cycle','forecastdate','grade']].head()     #select specific rows
# Out:
#    cycle forecastdate grade
# 0   2016      11/8/16    A+
# 1   2016      11/8/16     B
# 2   2016      11/8/16    A-
# 3   2016      11/8/16     B
# 4   2016      11/8/16    B-

# %%
data['grade'].unique()       #select unique values
# Out:
# array(['A+', 'B', 'A-', 'B-', 'A', nan, 'B+', 'C+', 'C-', 'C', 'D'],
#       dtype=object)

# %%
data['grade'].nunique()    #No of unique values
# Out:
# 10

# %%
data.nunique()   #for all columns
# Out:
# cycle                   1
# branch                  1
# type                    3
# matchup                 1
# forecastdate            1
# state                  57
# startdate             352
# enddate               345
# pollster              196
# grade                  10
# samplesize           1766
# population              4
# poll_wt              4399
# rawpoll_clinton      1312
# rawpoll_trump        1385
# rawpoll_johnson       584
# rawpoll_mcmullin       16
# adjpoll_clinton     12569
# adjpoll_trump       12582
# adjpoll_johnson      6629
# adjpoll_mcmullin       57
# multiversions           1
# url                  1304
# poll_id              4208
# question_id          4208
# createddate           222
# timestamp               3
# dtype: int64

# %%
data.apply(pd.unique)   #for all unique values in whole datasets
# Out:
# cycle                                                          [2016]
# branch                                                    [President]
# type                               [polls-plus, now-cast, polls-only]
# matchup                               [Clinton vs. Trump vs. Johnson]
# forecastdate                                                [11/8/16]
# state               [U.S., New Mexico, Virginia, Iowa, Wisconsin, ...
# startdate           [11/3/2016, 11/1/2016, 11/2/2016, 11/4/2016, 1...
# enddate             [11/6/2016, 11/7/2016, 11/5/2016, 11/4/2016, 1...
# pollster            [ABC News/Washington Post, Google Consumer Sur...
# grade                       [A+, B, A-, B-, A, nan, B+, C+, C-, C, D]
# samplesize          [2220.0, 26574.0, 2195.0, 3677.0, 16639.0, 129...
# population                                             [lv, rv, a, v]
# poll_wt             [8.720654, 7.628472, 6.424334, 6.087135, 5.316...
# ...

# %% [markdown]
# ### Value Count

# %%
data['state'].value_counts()    #counts no of occurence for each value of a given column
# Out:
# U.S.                    3318
# Florida                  444
# North Carolina           375
# Pennsylvania             375
# Ohio                     345
# New Hampshire            336
# Nevada                   279
# Virginia                 273
# Michigan                 258
# Wisconsin                240
# Georgia                  240
# Colorado                 240
# Arizona                  237
# California               213
# Iowa                     210
# Missouri                 204
# Utah                     198
# New York                 189
# Illinois                 180
# Texas                    174
# Indiana                  168
# New Jersey               162
# Oregon                   162
# Maine                    159
# South Carolina           156
# Washington               153
# Massachusetts            153
# New Mexico               153
# Kansas                   153
# Louisiana                150
# Kentucky                 147
# Idaho                    144
# ...

# %%
data['state'].value_counts(normalize = True)       #To see the percentage of value count
# Out:
# U.S.                    0.262833
# Florida                 0.035171
# North Carolina          0.029705
# Pennsylvania            0.029705
# Ohio                    0.027329
# New Hampshire           0.026616
# Nevada                  0.022101
# Virginia                0.021625
# Michigan                0.020437
# Wisconsin               0.019011
# Georgia                 0.019011
# Colorado                0.019011
# Arizona                 0.018774
# California              0.016873
# Iowa                    0.016635
# Missouri                0.016160
# Utah                    0.015684
# New York                0.014971
# Illinois                0.014259
# Texas                   0.013783
# Indiana                 0.013308
# New Jersey              0.012833
# Oregon                  0.012833
# Maine                   0.012595
# South Carolina          0.012357
# Washington              0.012120
# Massachusetts           0.012120
# New Mexico              0.012120
# ...

# %%
data[['state','grade']].value_counts()  #counts the occurence of value that matches 2 columns eg. states U.S. has A- 
#grade 1215 times, C+ grade 546 times, wisconsin has c- grade 42 times
# Out:
# state          grade
# U.S.           A-       1215
#                C+        546
#                B         162
#                C-        126
#                A+        114
#                         ...
# Nebraska CD-1  B           3
# Indiana        A           3
# Nebraska CD-2  B           3
# Missouri       A           3
# Mississippi    C           3
# Length: 321, dtype: int64

# %%
data[['state','grade']].value_counts().head(10)
# Out:
# state           grade
# U.S.            A-       1215
#                 C+        546
#                 B         162
#                 C-        126
#                 A+        114
#                 B+        105
#                 B-         96
# New Hampshire   B          90
# U.S.            A          87
# North Carolina  B+         81
# dtype: int64

# %%
data.shape
# Out:
# (12624, 27)

# %%
data.drop(columns = ['cycle','branch'], inplace = False)
# Out:
#              type                        matchup forecastdate          state  \
# 0      polls-plus  Clinton vs. Trump vs. Johnson      11/8/16           U.S.
# 1      polls-plus  Clinton vs. Trump vs. Johnson      11/8/16           U.S.
# 2      polls-plus  Clinton vs. Trump vs. Johnson      11/8/16           U.S.
# 3      polls-plus  Clinton vs. Trump vs. Johnson      11/8/16           U.S.
# 4      polls-plus  Clinton vs. Trump vs. Johnson      11/8/16           U.S.
# ...           ...                            ...          ...            ...
# 12619  polls-only  Clinton vs. Trump vs. Johnson      11/8/16  New Hampshire
# 12620  polls-only  Clinton vs. Trump vs. Johnson      11/8/16      Wisconsin
# 12621  polls-only  Clinton vs. Trump vs. Johnson      11/8/16       New York
# 12622  polls-only  Clinton vs. Trump vs. Johnson      11/8/16       Virginia
# 12623  polls-only  Clinton vs. Trump vs. Johnson      11/8/16      Wisconsin
#
# ...

# %%
data.shape
# Out:
# (12624, 27)

# %%
data1 = data.drop(columns = ['cycle','branch'], inplace = False)
data1
# Out:
#              type                        matchup forecastdate          state  \
# 0      polls-plus  Clinton vs. Trump vs. Johnson      11/8/16           U.S.
# 1      polls-plus  Clinton vs. Trump vs. Johnson      11/8/16           U.S.
# 2      polls-plus  Clinton vs. Trump vs. Johnson      11/8/16           U.S.
# 3      polls-plus  Clinton vs. Trump vs. Johnson      11/8/16           U.S.
# 4      polls-plus  Clinton vs. Trump vs. Johnson      11/8/16           U.S.
# ...           ...                            ...          ...            ...
# 12619  polls-only  Clinton vs. Trump vs. Johnson      11/8/16  New Hampshire
# 12620  polls-only  Clinton vs. Trump vs. Johnson      11/8/16      Wisconsin
# 12621  polls-only  Clinton vs. Trump vs. Johnson      11/8/16       New York
# 12622  polls-only  Clinton vs. Trump vs. Johnson      11/8/16       Virginia
# 12623  polls-only  Clinton vs. Trump vs. Johnson      11/8/16      Wisconsin
#
# ...

# %%
data
# Out:
#        cycle     branch        type                        matchup  \
# 0       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 1       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 2       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 3       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 4       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# ...      ...        ...         ...                            ...
# 12619   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12620   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12621   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12622   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12623   2016  President  polls-only  Clinton vs. Trump vs. Johnson
#
#       forecastdate          state   startdate    enddate  \
# 0          11/8/16           U.S.   11/3/2016  11/6/2016
# ...

# %% [markdown]
# ## Basics of Dictionary

# %%
## Basics of Dictionary
dict_1 = {"ontario":"Toronto","Manitoba":"winipeg",
         "BC":"vancouver"}
dict_1
# Out:
# {'ontario': 'Toronto', 'Manitoba': 'winipeg', 'BC': 'vancouver'}

# %%
for i in dict_1.items():
    print(i)
# Out:
# ('ontario', 'Toronto')
# ('Manitoba', 'winipeg')
# ('BC', 'vancouver')

# %%
for k,v in dict_1.items():
    print(v)
# Out:
# Toronto
# winipeg
# vancouver

# %%
dict_2 = {"ontario":["Toronto","Abbotsford"],"Manitoba":["Winipeg","Brandon"],"BC":["Vancouver","Victoria","Vernon"]}
dict_2.items()
# Out:
# dict_items([('ontario', ['Toronto', 'Abbotsford']), ('Manitoba', ['Winipeg', 'Brandon']), ('BC', ['Vancouver', 'Victoria', 'Vernon'])])

# %%
for k,v in dict_2.items():
    print(v[1])
# Out:
# Abbotsford
# Brandon
# Victoria

# %%
needed_cols = ['rawpoll_trump',"rawpoll_johnson"]
data[needed_cols]
# Out:
#        rawpoll_trump  rawpoll_johnson
# 0              43.00             4.00
# 1              35.69             5.46
# 2              39.00             6.00
# 3              41.00             5.00
# 4              43.00             3.00
# ...              ...              ...
# 12619          37.00            10.00
# 12620          38.96              NaN
# 12621          25.00             9.00
# 12622          39.05              NaN
# 12623          37.00              NaN
#
# [12624 rows x 2 columns]

# %%
data.rename(columns = {'rawpoll_trump':'clinton_beleivers_percentage',
                      'rawpoll_johnson':'johnson_belivers_percentage'},
           inplace = True)

# %%
data.columns
# Out:
# Index(['cycle', 'branch', 'type', 'matchup', 'forecastdate', 'state',
#        'startdate', 'enddate', 'pollster', 'grade', 'samplesize', 'population',
#        'poll_wt', 'rawpoll_clinton', 'clinton_beleivers_percentage',
#        'johnson_belivers_percentage', 'rawpoll_mcmullin', 'adjpoll_clinton',
#        'adjpoll_trump', 'adjpoll_johnson', 'adjpoll_mcmullin', 'multiversions',
#        'url', 'poll_id', 'question_id', 'createddate', 'timestamp'],
#       dtype='object')

# %%
data.shape
# Out:
# (12624, 27)

# %%
#data.drop(columns = ['cycle','branch'], inplace = False)
data.drop(columns = ['cycle','branch'],inplace = True)

# %%
data.columns
# Out:
# Index(['type', 'matchup', 'forecastdate', 'state', 'startdate', 'enddate',
#        'pollster', 'grade', 'samplesize', 'population', 'poll_wt',
#        'rawpoll_clinton', 'clinton_beleivers_percentage',
#        'johnson_belivers_percentage', 'rawpoll_mcmullin', 'adjpoll_clinton',
#        'adjpoll_trump', 'adjpoll_johnson', 'adjpoll_mcmullin', 'multiversions',
#        'url', 'poll_id', 'question_id', 'createddate', 'timestamp'],
#       dtype='object')
